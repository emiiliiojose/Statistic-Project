# %% [markdown]
# -Explore and clean data

# %%
import pandas as pd

df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')

# %%
df_train.sort_values('customer_id', inplace=True)
df_train
# Out:
#      customer_id  age     income signup_channel  country  account_duration  \
# 0     CUST100000   56   41315.55            web  Germany                 4
# 1     CUST100001   69   50955.33       Referral  Germany                30
# 2     CUST100002   46   57079.42            web       UK                30
# 3     CUST100003   32   52088.23           APP    Canada                13
# 4     CUST100004   60  340461.50            Web    India                42
# ...          ...  ...        ...            ...      ...               ...
# 2693  CUST102693   27   58571.13            Web       US                59
# 2694  CUST102694   20   61771.72            app    India                13
# 2695  CUST102695   71   59322.83            Web  Germany                52
# 2696  CUST102696   31   45010.14            app  Germany                48
# 2697  CUST102697   33   66405.46           APP        UK                42
#
# ...

# %%
df_test.sort_values('customer_id', inplace=True)
df_test
# Out:
#     customer_id  age    income signup_channel  country  account_duration  \
# 0    CUST102698   27  48133.59           APP        US                27
# 1    CUST102699   46  41464.59       Referral   Canada                53
# 2    CUST102700   27  41684.93            app    India                 2
# 3    CUST102701   29  79099.83            web       US                34
# 4    CUST102702   47  38870.25           APP        US                31
# ..          ...  ...       ...            ...      ...               ...
# 297  CUST102995   37  26426.33           APP     India                 1
# 298  CUST102996   21  38093.20            web   Canada                19
# 299  CUST102997   71  52240.34       Referral  Germany                46
# 300  CUST102998   24  46921.57            app  Germany                 3
# 301  CUST102999   71  32402.65       referral       US                 2
#
#      last_login_days  num_transactions  support_tickets premium_user  \
# ...

# %%
df_test_sub = df_test.drop(columns=['customer_id','signup_channel','country',])
df_test_sub['premium_user'] = df_test_sub['premium_user'].replace({'Y': 1, 'YES': 1, 'Yes': 1, 'yes': 1, 'y': 1, 'N': 0, 'NO': 0, 'No': 0, 'no': 0, 'n': 0,' YES ':1, ' NO ':0})
df_test_sub['premium_user'] = df_test_sub['premium_user'].astype(int)
df_test_sub
# Out:
# C:\Users\Aliando\AppData\Local\Temp\ipykernel_27532\599400350.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test_sub['premium_user'] = df_test_sub['premium_user'].replace({'Y': 1, 'YES': 1, 'Yes': 1, 'yes': 1, 'y': 1, 'N': 0, 'NO': 0, 'No': 0, 'no': 0, 'n': 0,' YES ':1, ' NO ':0})
#      age    income  account_duration  last_login_days  num_transactions  \
# 0     27  48133.59                27              NaN                 7
# 1     46  41464.59                53              NaN                10
# 2     27  41684.93                 2            167.0                16
# 3     29  79099.83                34            144.0                13
# 4     47  38870.25                31            185.0                14
# ...

# %%
df_test_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 302 non-null    int64
#  1   income              302 non-null    float64
#  2   account_duration    302 non-null    int64
#  3   last_login_days     268 non-null    float64
#  4   num_transactions    302 non-null    int64
#  5   support_tickets     302 non-null    int64
#  6   premium_user        302 non-null    int64
#  7   satisfaction_score  268 non-null    float64
# dtypes: float64(3), int64(5)
# memory usage: 19.0 KB

# %%
df_train_sub = df_train.drop(columns=['customer_id','signup_channel','country',])
df_train_sub['premium_user'] = df_train_sub['premium_user'].replace({'Y': 1, 'YES': 1, 'Yes': 1, 'yes': 1, 'y': 1, 'N': 0, 'NO': 0, 'No': 0, 'no': 0, 'n': 0,' YES ':1, ' NO ':0})
df_train_sub['premium_user'] = df_train_sub['premium_user'].astype(int)
df_train_sub
# Out:
# C:\Users\Aliando\AppData\Local\Temp\ipykernel_27532\1379130154.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train_sub['premium_user'] = df_train_sub['premium_user'].replace({'Y': 1, 'YES': 1, 'Yes': 1, 'yes': 1, 'y': 1, 'N': 0, 'NO': 0, 'No': 0, 'no': 0, 'n': 0,' YES ':1, ' NO ':0})
#       age     income  account_duration  last_login_days  num_transactions  \
# 0      56   41315.55                 4             55.0                11
# 1      69   50955.33                30            228.0                 9
# 2      46   57079.42                30            144.0                 9
# 3      32   52088.23                13             91.0                 5
# 4      60  340461.50                42             81.0                 3
# ...

# %%
X_train, y_train = df_train_sub.to_numpy()[:, :-1], df_train_sub.to_numpy()[:, -1]
y_train
# Out:
# array([1., 0., 0., ..., 0., 1., 0.], shape=(2698,))

# %%
# Out:
# ((2698, 8), (2698,))

# %%
from sklearn.linear_model import LogisticRegression

# Fix: instantiate LogisticRegression first, then call fit()
lr = LogisticRegression().fit(X_train, y_train)
lr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 # Fix: instantiate LogisticRegression first, then call fit()
# ----> 4 lr = LogisticRegression().fit(X_train, y_train)
#       5 lr
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# ...
